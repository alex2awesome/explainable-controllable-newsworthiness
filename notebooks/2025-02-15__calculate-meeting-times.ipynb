# %%
import pandas as pd

# %%
ls ../data/seattle/seattle__policy_info.csv
# Out:
# ../data/seattle/seattle__policy_info.csv

# %%
pd.read_csv('../data/seattle/seattle__meeting_info.csv')
# Out:
#                                                    Name  \
# 0     Libraries, Education, and Neighborhoods Committee
# 1                              Transportation Committee
# 2     Sustainability, City Light, Arts and Culture C...
# 3                                          City Council
# 4                                      Council Briefing
# ...                                                 ...
# 3188  Seattle Public Utilities and Neighborhoods Com...
# 3189  Planning, Land Use, and Sustainability Committ...
# 3190      Education and Governance Committee (inactive)
# 3191                                   Council Briefing
# 3192  Committee on Housing Affordability, Human Serv...
#
#                                               Name_href Meeting Date  \
# 0     DepartmentDetail.aspx?ID=52009&GUID=38285AE7-6...    5/23/2024
# 1     DepartmentDetail.aspx?ID=28355&GUID=6F1655EA-6...    5/21/2024
# 2     DepartmentDetail.aspx?ID=52012&GUID=42C5CF02-7...    5/17/2024
# ...
